# %% [markdown]
# Whatever this is.
#   ![testing this](attachment:data-sources-PWT-1.png)
#
# <div style="max-width:400px;margin-left: auto; margin-right: 0;">
#   ![testing this](attachment:data-sources-PWT-1.png)
# </div>

# %%
from python.display import Image
from core.display import HTML 
Image(filename = PATH + "My_picture.jpg", width=100, height=100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 from python.display import Image
#       2 from core.display import HTML
#       3 Image(filename = PATH + "My_picture.jpg", width=100, height=100)
#
# ModuleNotFoundError: No module named 'python'
