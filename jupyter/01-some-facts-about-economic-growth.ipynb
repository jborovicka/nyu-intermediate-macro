# %% [markdown]
# # Topic 1: Some facts about economic growth
#
# This lecture provide a summary of basic empirical facts that we will study in this course. This Jupyter Notebook reproduces all graphs used in the lecture slides. It relies on the <tt>Pandas</tt> library in Python to download data from various economic databases.

# %%
# load definitions
# %matplotlib inline
from defs_intermediate_macro import *
# %run defs_intermediate_macro

# %%
today = datetime.date.today().strftime('%d %B %Y')
print('Last update:',today) # '2021-05-03'
# Out:
# Last update: 04 May 2023

# %% [markdown]
# # U.S. Gross Domestic Product
#
# U.S. GDP data from the <a href="https://fred.stlouisfed.org/">FRED database</a> at the Federal Reserve Bank of St. Louis.

# %%
# real GDP
data = myLoadDataFRED(series=['GDPC1'],transform='none')

param = {'title': '',
         'xlim': [1998,2022.5], 'ylim': [11000,20000],
         'xlabel': '', 'ylabel': 'Billions of Chained 2012 Dollars',
         'ylogscale': True,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [11000,20000]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['GDPC1'],
                    linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Real Gross Domestic Product')
x = ax.legend(loc='upper left')

# %%
# real GDP growth rate
data = myLoadDataFRED(series=['GDPC1'],transform='pct_change_year_ago')

param = {'title': '',
         'xlim': [1948,2022.5], 'ylim': [-10,15],
         'xlabel': '', 'ylabel': 'Percent Change from Year Ago',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-10,15]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['GDPC1'],
                    linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Real Gross Domestic Product')
x = ax.legend(loc='lower left')

# %%
# real GDP growth rate, annual data over a longer sample
data = myLoadDataFRED(series=['GDPCA'],transform='pct_change_year_ago')

param = {'title': '',
         'xlim': [1930,2022.5], 'ylim': [-15,20],
         'xlabel': '', 'ylabel': 'Percent Change from Year Ago',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-15,20]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['GDPCA'],
                    linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Real Gross Domestic Product')
x = ax.legend(loc='lower left')

# %% [markdown]
# # Unemployment
#
# U.S. unemployment data from the <a href="https://fred.stlouisfed.org/">FRED database</a> at the Federal Reserve Bank of St. Louis.

# %%
data = myLoadDataFRED(series=['UNRATE'],transform='none')

param = {'title': '',
         'xlim': [1947.5,2023], 'ylim': [0,15],
         'xlabel': '', 'ylabel': 'Percent',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,15]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['UNRATE'],
                    linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Unemployment Rate')
ax.plot([data['year'][0],data['year'][-1]],[5,5],'--',linewidth=3,color=myColor['tolVibrantRed'])
x = ax.legend(loc='upper left')

# %% [markdown]
# # Inflation
#
# U.S. inflation data from the <a href="https://fred.stlouisfed.org/">FRED database</a> at the Federal Reserve Bank of St. Louis.

# %%
# inflation (increase in CPI) and core inflation
data = myLoadDataFRED(series=['CPIAUCSL','CPILFESL'],transform='pct_change_year_ago')

param = {'title': '',
         'xlim': [1998,2023], 'ylim': [-2,10],
         'xlabel': '', 'ylabel': 'Percent Change from Year Ago',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-2,10]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['CPIAUCSL'],
                    '--',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Consumer Price Index: All Items')
ax.plot(data['year'],data['CPILFESL'],
                    linewidth=3,marker='',color=myColor['tolVibrantOrange'],label='Consumer Price Index: All Items Less Food and Energy')
x = ax.legend(loc='upper left')

# %%
# inflation data over a longer sample
data = myLoadDataFRED(series=['CPIAUCNS','CPILFESL'],transform='pct_change_year_ago')

param = {'title': '',
         'xlim': [1910,2023], 'ylim': [-20,25],
         'xlabel': '', 'ylabel': 'Percent Change from Year Ago',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-20,25]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['CPIAUCNS'],
                    '--',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Consumer Price Index: All Items')
ax.plot(data['year'],data['CPILFESL'],
                    linewidth=3,marker='',color=myColor['tolVibrantOrange'],label='Consumer Price Index: All Items Less Food and Energy')
x = ax.legend(loc='upper right')

# %% [markdown]
# # Monetary policy
#
# Interest rate data from the <a href="https://fred.stlouisfed.org/">FRED database</a> at the Federal Reserve Bank of St. Louis.

# %%
data = myLoadDataFRED(series=['FEDFUNDS'],transform='none')

param = {'title': '',
         'xlim': [1998,2023], 'ylim': [0,7],
         'xlabel': '', 'ylabel': 'Percent Change from Year Ago',
         'ylogscale': False,
         'showgrid': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,7]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['FEDFUNDS'],
                    '-',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Effective Federal Funds Rate')
x = ax.legend(loc='upper right')

# %% [markdown]
# <a href="https://www.clevelandfed.org/~/media/files/webcharts/crediteasing/crediteasingbalancesheet.xls">Federal Reserve balance sheet data</a> from the Federal Reserve Bank of Cleveland.

# %%
# load and process the spreadsheet
data_Clev_orig = pd.read_excel('https://www.clevelandfed.org/~/media/files/webcharts/crediteasing/crediteasingbalancesheet.xls',sheet_name="Chart Data")
data_Clev_orig.columns = data_Clev_orig.iloc[0,:]
data_Clev_orig = data_Clev_orig.iloc[1:,:]
data_Clev_orig = data_Clev_orig.set_index('Date')
dates = year_frac(data_Clev_orig.index)
T = len(dates)

# keep only relevant columns, and convert to float
data_columns = ['Traditional Security Holdings','Lending to Financial Institutions',
                'Liquidity to Key Credit Markets','Federal Agency Debt and Mortgage-Backed Securities Purchases',
                'Long-Term Treasury Purchases']
data_Clev_orig = data_Clev_orig[data_columns]
data_Clev_orig = data_Clev_orig.astype('float64')

# change index to numerical years if needed
# data_Clev_orig.reset_index(drop=True,inplace=True)
# data_Clev_orig['date_num'] = dates
# data_Clev_orig = data_Clev_orig.set_index('date_num')

param = {'title': '',
         'xlim': [2007,2023.67], 'ylim': [0,9000],
         'xlabel': '', 'ylabel': 'Billions of USD',
         'ylogscale': False,
         'showgrid': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,9000]}

fig,ax = myGenerateTSPlot(param)

import matplotlib.patches as mpatches
cumval = np.zeros(T) + data_Clev_orig[data_columns[0]]*0.0

legend_patches = []
for ind,lab in enumerate(data_columns):
    cumvalinc = cumval + data_Clev_orig[lab].to_numpy()/1000
    ax.fill_between(dates,cumval,cumvalinc,color=clist_1[ind])
    cumval = cumvalinc
    legend_patches.append(mpatches.Patch(color=clist_1[ind],label=data_Clev_orig[lab].name))

ax.legend(handles=legend_patches,loc='upper left');

# alternative way of plotting the same data using the data.plot.area function
#ax = data_Clev_orig.plot.area(color=[myColor['tolVibrantBlue'],
#                           myColor['tolVibrantOrange'],
#                           myColor['tolVibrantCyan'],
#                           myColor['tolVibrantMagenta'],
#                           myColor['tolVibrantTeal']],
#                    linewidth=0)
#ax.grid(color=myColor['tolPaleGrey'],linestyle=':')

# %% [markdown]
# # Fiscal policy
#
# ## FRED
#
# Federal government finance data from the <a href="https://fred.stlouisfed.org/">FRED database</a> at the Federal Reserve Bank of St. Louis.

# %%
data = myLoadDataFRED(series=['FYFSDFYGDP'],transform='none')

param = {'title': '',
         'xlim': [1930,2023], 'ylim': [-30,5],
         'xlabel': '', 'ylabel': 'Percent of GDP',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-30,5]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['FYFSDFYGDP'],
                    '-',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Federal Surplus or Deficit [-] as Percent of GDP')
x = ax.legend(loc='lower right')

# %% [markdown]
# Composition of government debt, a discussion on constructing relevant measures of government debt held by public see <a href="https://fredblog.stlouisfed.org/2019/12/a-lesson-in-measuring-the-federal-debt/">this note</a> by researchers at the Federal Reserve Bank of St. Louis.

# %%
data = myLoadDataFRED(series=['GFDEGDQ188S','FYGFGDQ188S','HBFRGDQ188S'],transform='none')
# Federal Debt: Total Public Debt as Percent of Gross Domestic Product (GFDEGDQ188S)
# Federal Debt Held by the Public as Percent of Gross Domestic Product (FYGFGDQ188S)
# Federal Debt Held by Federal Reserve Banks as Percent of Gross Domestic Product (HBFRGDQ188S)

param = {'title': 'Composition of Federal Debt',
         'xlim': [1970,data['year'][-1]], 'ylim': [0,140],
         'xlabel': '', 'ylabel': 'Percent of GDP',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,140]}

fig,ax = myGenerateTSPlot(param)

data_proc = dict()
data_proc['Federal Debt Held by Public (excl. Fed)'] = data['FYGFGDQ188S']-data['HBFRGDQ188S'] # excludes debt held by the Fed
data_proc['Federal Debt Held by Federal Reserve'] = data['HBFRGDQ188S']
data_proc['Federal Debt Held by Government Agencies'] = data['GFDEGDQ188S']-data['FYGFGDQ188S']

import matplotlib.patches as mpatches
T = len(data['year'])
cumval = np.zeros(T)
legend_patches = []
for ind,lab in enumerate(data_proc):
    ax.fill_between(data['year'],cumval,cumval+data_proc[lab],color=clist_1[ind])
    cumval = cumval+data_proc[lab]
    legend_patches.append(mpatches.Patch(color=clist_1[ind],label=lab))

ax.legend(handles=legend_patches,loc='upper left');

# %% [markdown]
# Historical debt data by the Congressional Budget Office.

# %%
# CBO data until 2000, remaining data from FRED
data_CBO_orig = pd.read_excel('https://www.cbo.gov/sites/default/files/cbofiles/ftpdocs/117xx/doc11766/historicaldebt2000.xls',sheet_name="Sheet1").to_numpy()
id_years = np.where(data_CBO_orig[:,0]*0 == 0,True,False)
data_CBO = dict()
data_CBO['year'] = data_CBO_orig[id_years,0]
data_CBO['debt_GDP'] = data_CBO_orig[id_years,1]
data_CBO['nominal_GDP'] = data_CBO_orig[id_years,2]
data_CBO['real_GDP'] = data_CBO_orig[id_years,3]

param = {'title': '',
         'xlim': [1790,2023], 'ylim': [0,120],
         'xlabel': '', 'ylabel': 'Percent of GDP',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,120]}

fig,ax = myGenerateTSPlot(param)

# data variable constructed in previous block - use for plotting data since 2000
ax.plot(data['year'][data['year']>=2000],data['FYGFGDQ188S'][data['year']>=2000],
                    '-',linewidth=3,marker='',color=myColor['tolVibrantOrange'],label='Federal Debt Held by Public (incl. Fed)')
ax.plot(data_CBO['year'],data_CBO['debt_GDP'],
                    '-',linewidth=3,marker='',color=myColor['tolVibrantOrange'])
x = ax.legend(loc='upper left')

# %%
data = myLoadDataFRED(series=['NA000283Q'],transform='none')

param = {'title': '',
         'xlim': [1995,2022.5], 'ylim': [0,2400],
         'xlabel': '', 'ylabel': 'Billions of USD',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,2400]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['NA000283Q']/1000,
                    '-',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Federal Government Current Expenditures (Quarterly)')
x = ax.legend(loc='upper left')

# %%
data = myLoadDataFRED(series=['NA000314Q'],transform='none')

param = {'title': '',
         'xlim': [1995,2022.5], 'ylim': [-1600,200],
         'xlabel': '', 'ylabel': 'Billions of USD',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-1600,0]}

fig,ax = myGenerateTSPlot(param)

ax.plot(data['year'],data['NA000314Q']/1000,
                    '-',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Net Federal Government Saving')
x = ax.legend(loc='lower left')

# %% [markdown]
# ## Eurostat
#
# Government finances of European Union countries from the <a href="https://ec.europa.eu/eurostat/data/database">Eurostat database</a>.

# %%
# load data - large dataset, may load slowly
start = datetime.datetime(1990,1,1)
end = datetime.datetime(2030,1,1)
data_Eurostat = pdr.data.DataReader('gov_10dd_edpt1','eurostat',start,end)
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Input In [16], in <cell line: 4>()
#       2 start = datetime.datetime(1990,1,1)
#       3 end = datetime.datetime(2030,1,1)
# ----> 4 data_Eurostat = pdr.data.DataReader('gov_10dd_edpt1','eurostat',start,end)
#
# File c:\progs\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File c:\progs\anaconda3\lib\site-packages\pandas_datareader\data.py:478, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     469     return OECDReader(
#     470         symbols=name,
#     471         start=start,
#    (...)
#     475         session=session,
#     476     ).read()
#     477 elif data_source == "eurostat":
# --> 478     return EurostatReader(
#     479         symbols=name,
#     480         start=start,
#     481         end=end,
#     482         retry_count=retry_count,
#     483         pause=pause,
#     484         session=session,
#     485     ).read()
#     486 elif data_source == "nasdaq":
#     487     if name != "symbols":
#
# File c:\progs\anaconda3\lib\site-packages\pandas_datareader\base.py:101, in _BaseReader.read(self)
#      99 """Read data from connector"""
#     100 try:
# --> 101     return self._read_one_data(self.url, self.params)
#     102 finally:
#     103     self.close()
#
# File c:\progs\anaconda3\lib\site-packages\pandas_datareader\eurostat.py:33, in EurostatReader._read_one_data(self, url, params)
#      32 def _read_one_data(self, url, params):
# ---> 33     resp_dsd = self._get_response(self.dsd_url)
#      34     dsd = _read_sdmx_dsd(resp_dsd.content)
#      36     resp = self._get_response(url)
#
# File c:\progs\anaconda3\lib\site-packages\pandas_datareader\base.py:181, in _BaseReader._get_response(self, url, params, headers)
#     178 if last_response_text:
#     179     msg += "\nResponse Text:\n{0}".format(last_response_text)
# --> 181 raise RemoteDataError(msg)
#
# RemoteDataError: Unable to read URL: http://ec.europa.eu/eurostat/SDMX/diss-web/rest/datastructure/ESTAT/DSD_gov_10dd_edpt1
# Response Text:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\n\t\t\n\t\t\t<!DOCTYPE html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html dir="ltr" lang="en-GB">\n\n<head>\n    <title>Status - Eurostat</title>\n<meta content="initial-scale=1.0, width=device-width" name="viewport" />\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<meta content="text/html; charset=UTF-8" http-equiv="content-type" />\n\n\n\n\n\n\n\n\n\n\n\r\n<meta name="google-site-verification" content="6XK2M_NqFEhF79UhdF43-Zv2t58zbBUp_CYAAKDHjgo" />\r\n<meta name="google-site-verification" content="in2pBF1QfAtURduPbpP5i-jI0MycWywIlnAImhgFALc" />\r\n<script type="text/javascript" src="/eurostat/ruxitagentjs_ICA2NVfgjqrux_10247220811100421.js" data-dtconfig="app=e63eebabdf39f376|agentId=aa1bb8432790755b|featureHash=ICA2NVfgjqrux|vcv=2|rdnt=1|uxrgce=1|bp=3|cuc=m097nmfl|mel=100000|dpvc=1|ssv=4|lastModification=1683183055606|dtVersion=10247220811100421|tp=500,50,0,1|uxdcw=1500|agentUri=/eurostat/ruxitagentjs_ICA2NVfgjqrux_10247220811100421.js|reportUrl=/eurostat/rb_39a3e95b-5423-482c-879b-99ef235dffeb|rid=RID_432720400|rpid=1572974635|domain=europa.eu/eurostat"></script><script type="application/ld+json">\r\n    {\r\n\t\t"@context": "https://schema.org",\r\n\t\t"@type": "GovernmentOrganization",\r\n\t\t"@id": "https://ec.europa.eu/eurostat/",\r\n\t\t"name": "Eurostat",\r\n\t\t"description": "Eurostat is the statistical office of the European Union. Its mission is to provide high quality statistics and data on Europe.",\r\n\t\t"url": "https://ec.europa.eu/eurostat/",\r\n\t\t"logo": "https://ec.europa.eu/eurostat/o/estat-theme/images/logo/4x3.png",\r\n\t\t"image": [\r\n\t\t\t"https://ec.europa.eu/eurostat/o/estat-theme/images/logo/1x1.png",\r\n\t\t\t"https://ec.europa.eu/eurostat/o/estat-theme/images/logo/4x3.png",\r\n\t\t\t"https://ec.europa.eu/eurostat/o/estat-theme/images/logo/16x9.png"\r\n\t\t],\r\n\t\t"address": {\r\n\t\t\t"@type": "PostalAddress",\r\n\t\t\t"addressLocality": "Luxembourg",\r\n\t\t\t"postalCode": "L-2721",\r\n\t\t\t"streetAddress": "5 Rue Alphonse Weicker"\r\n\t\t},\r\n\t\t"geo": {\r\n\t\t\t"@type": "GeoCoordinates",\r\n\t\t\t"latitude": 49.633182,\r\n\t\t\t"longitude": 6.169437\r\n\t\t},\r\n\t\t"telephone": "+35243011",\r\n\t\t"foundingDate": "1953",\r\n\t\t"memberOf": [{\r\n\t\t\t"@type": "GovernmentOrganization",\r\n\t\t\t"name": "European Commission",\r\n\t\t\t"url": "https://ec.europa.eu/"\r\n\t\t}],\r\n\t\t"sameAs": [\r\n\t\t\t"https://en.wikipedia.org/wiki/Eurostat",\r\n\t\t\t"https://twitter.com/EU_Eurostat",\r\n\t\t\t"https://www.facebook.com/EurostatStatistics",\r\n\t\t\t"https://www.instagram.com/eu_eurostat",\r\n\t\t\t"https://www.linkedin.com/company/eurostat/",\r\n\t\t\t"https://youtube.com/c/Eurostat-EC"\r\n\t\t]\r\n    }\r\n</script>\n\n<link data-senna-track="permanent" href="/eurostat/o/frontend-theme-font-awesome-web/css/main.css" rel="stylesheet" type="text/css" />\n<script data-senna-track="permanent" src="/eurostat/combo?browserId=other&minifierType=js&languageId=en_GB&t=1681330545937&/eurostat/o/frontend-js-jquery-web/jquery/jquery.min.js&/eurostat/o/frontend-js-jquery-web/jquery/bootstrap.bundle.min.js&/eurostat/o/frontend-js-jquery-web/jquery/collapsible_search.js&/eurostat/o/frontend-js-jquery-web/jquery/fm.js&/eurostat/o/frontend-js-jquery-web/jquery/form.js&/eurostat/o/frontend-js-jquery-web/jquery/popper.min.js&/eurostat/o/frontend-js-jquery-web/jquery/side_navigation.js" type="text/javascript"></script>\n\n\n<link href="https://ec.europa.eu/eurostat/o/estat-theme-ecl/images/favicon.ico" rel="icon" />\n\n\n\n\n\n\t\n\n\t\t\n\t\t\t\n\t\t\t\t<link data-senna-track="temporary" href="https://ec.europa.eu/eurostat" rel="canonical" />\n\t\t\t\n\t\t\n\n\t\n\n\t\t\n\t\t\t\n\t\t\t\t<link data-senna-track="temporary" href="https://ec.europa.eu/eurostat/fr/" hreflang="fr-FR" rel="alternate" />\n\t\t\t\n\t\t\t\n ...

# %%
# process data - deficits
country_list = {'European Union':'European Union - 27 countries (from 2020)',
                #'Euro area':'Euro area - 19 countries  (from 2015)',
                'Germany':'Germany (until 1990 former territory of the FRG)',
                'France':'France',
                'Spain':'Spain',
                'Italy':'Italy',
                'Greece':'Greece'}
d_def={}
d_def_frame = data_Eurostat.loc[:,('Net lending (+) /net borrowing (-)','Percentage of gross domestic product (GDP)','General government',slice(None))]
var = ['Net lending (+) /net borrowing (-)','Percentage of gross domestic product (GDP)','General government','','Annual']

param = {'title': '',
         'xlim': [2006,2021], 'ylim': [-16,4],
         'xlabel': '', 'ylabel': 'Percent of GDP',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': False, 'showNBERrecessions_y': [-30,5]}

fig,ax = myGenerateTSPlot(param)

for ind,i in enumerate(country_list):
    var[3] = country_list[i]
    d_def[i] = d_def_frame.loc[:,tuple(var)].to_numpy()
    if ind == 0:
        ax.plot(year_frac(d_def_frame.index),d_def[i],
                            '--',linewidth=3,marker='',color='#000000',label=i)
    else:
        ax.plot(year_frac(d_def_frame.index),d_def[i],
                            '-',linewidth=3,marker='',color=clist_1[ind-1],label=i)
    
ax.legend(loc='lower left');

# %%
# process data - debt
d_debt={}
d_debt_frame = data_Eurostat.loc[:,('Government consolidated gross debt','Percentage of gross domestic product (GDP)','General government',slice(None))]
var = ['Government consolidated gross debt','Percentage of gross domestic product (GDP)','General government','','Annual']

param = {'title': '',
         'xlim': [1995,2021], 'ylim': [0,220],
         'xlabel': '', 'ylabel': 'Percent of GDP',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': False, 'showNBERrecessions_y': [-30,5]}

fig,ax = myGenerateTSPlot(param)

for ind,i in enumerate(country_list):
    var[3] = country_list[i]
    d_debt[i] = d_debt_frame.loc[:,tuple(var)].to_numpy()
    if ind == 0:
        ax.plot(year_frac(d_debt_frame.index),d_debt[i],
                            '--',linewidth=3,marker='',color='#000000',label=i)
    else:
        ax.plot(year_frac(d_debt_frame.index),d_debt[i],
                            '-',linewidth=3,marker='',color=clist_1[ind-1],label=i)
    
ax.plot(param['xlim'],[60,60],':',linewidth=3,marker='',color=myColor['tolVibrantGrey'],label='Maastricht Criteria Limit')
ax.legend(loc='upper left');

# %% [markdown]
# ## OECD
#
# Economic data from the <a href="https://stats.oecd.org/">Organisation for Economic Co-operation and Development database</a>. The <tt>OECDReaderSeries</tt> function used to download individual series is experimental and should be used with caution. The standard <tt>OECDReader</tt> function downloads whole datasets that are often very large and downloads may time out.

# %%
# Use modified reader function that allows to download only a specific series, whole datasets may be too large.
# To download whole dataset, use, e.g., NAAG/all
# dataset: National Accounts at a Glance
# series: Net lending/net borrowing, general government, percentage of GDP, all countries
datareader = OECDReaderSeries('NAAG/.B9S13S',start='JAN-01-2006')
data_def = datareader.read()
#datareader = OECDReaderSeries('SNA_TABLE1/.B1_GA.G',start='JAN-01-2006')
datareader = OECDReaderSeries('NAAG/.GDPG',start='JAN-01-2006')
data_growth = datareader.read()

# %%
def_year2009ind = np.where(data_def.index.year == 2009)[0][0]
def_country_names = data_def.columns.droplevel(1)
def_year2009 = data_def.to_numpy()[def_year2009ind,:]

growth_year2009ind = np.where(data_growth.index.year == 2009)[0][0]
growth_country_names = data_growth.columns.droplevel(1)
growth_year2009 = data_growth.to_numpy()[growth_year2009ind,:]

# merge data for growth and deficits
country_names_set = set(def_country_names).intersection(set(growth_country_names))
data = {'country_names':[], 'deficit':[], 'growth':[]}

for ind,cname in enumerate(country_names_set):
    def_ind = np.where(def_country_names == cname)
    growth_ind = np.where(growth_country_names == cname)
    if not(np.isnan(def_year2009[def_ind])) and not(np.isnan(growth_year2009[growth_ind])):
        data['country_names'].append(cname)
        data['deficit'].append(float(def_year2009[def_ind]))
        data['growth'].append(float(growth_year2009[growth_ind]))

# rename some data
name_switch = [["China (People's Republic of)",'China'],
               ['Slovak Republic','Slovakia'],
               ['Czech Republic','Czechia']]
for n in name_switch:
    for ind,old_name in enumerate(data['country_names']):
        if n[0]==old_name:
            data['country_names'][ind] = n[1]
            
# sort data
args = np.argsort(data['growth'])
data['deficit'] = [data['deficit'][i] for i in args]
data['growth'] = [data['growth'][i] for i in args]
data['country_names'] = [data['country_names'][i] for i in args]

N_data = len(data['country_names'])
loc_data = np.arange(N_data)
   
param = {'title': '','figsize' : [18,9],
         'xlim': [-0.5,N_data-0.5],'ylim': [-16,12],
         'xlabel': '', 'ylabel': 'Deficit in Percent of GDP / Growth in Percent',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': False, 'showNBERrecessions_y': [-30,5]}

fig,ax = myGenerateBarPlot(param)
bar_width = 0.4

ax.bar(loc_data-bar_width/2,data['deficit'],bar_width,color=myColor['tolVibrantBlue'],label='2009 General Government Deficit')
ax.bar(loc_data+bar_width/2,data['growth'],bar_width,color=myColor['tolVibrantOrange'],label='2009 GDP Growth')
ax.set_xticks(ticks=np.linspace(0,N_data-1,len(data['country_names'])))
ax.set_xticklabels(data['country_names'],rotation='vertical');
ax.legend(loc='upper left');

# %% [markdown]
# # Long-Run Growth
#
# ## Maddison Project
#
# Historical estimates of GDP per capita in Purchasing Power Parity terms from the <a href="https://www.rug.nl/ggdc/historicaldevelopment/maddison/">Maddison project</a> website.

# %%
# Maddison project data
data_Mad_orig_tab = pd.read_excel('https://www.rug.nl/ggdc/historicaldevelopment/maddison/data/mpd2020.xlsx',sheet_name="GDP pc")
data_Mad_orig = data_Mad_orig_tab.to_numpy()

# %%
# data_Mad['GDP_USA'][data_Mad['year']==1900]

# %%
id_years = np.where(data_Mad_orig[:,0]*0 == 0,True,False)
country_codes = data_Mad_orig[0,1:]
data_Mad_GDP_pc = data_Mad_orig[id_years,1:]
country_names = data_Mad_orig_tab.columns.to_numpy()
country_names = country_names[1:]

data_Mad = dict()
data_Mad['year'] = data_Mad_orig[id_years,0]
data_Mad['GDP_USA'] = data_Mad_GDP_pc[:,np.where(country_codes=='USA')[0][0]]

param = {'title': '',
         'xlim': [1799,2021], 'ylim': [0,60000],
         'xlabel': '', 'ylabel': '2011 U.S. dollars',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,60000]}

fig,ax = myGenerateTSPlot(param)

# data variable constructed in previous block - use for plotting data since 2000
ax.plot(data_Mad['year'],data_Mad['GDP_USA'],
                    '-',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='U.S. GDP per capita')
ax.legend(loc='upper left');

# %%
param = {'title': '',
         'xlim': [1799,2021], 'ylim': [2000,64000],
         'xlabel': '', 'ylabel': '2011 U.S. dollars',
         'ylogscale': True,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [0,64000]}

fig,ax = myGenerateTSPlot(param)

# data variable constructed in previous block - use for plotting data since 2000
ax.plot(np.linspace(1800,2021,100),2000*np.exp(0.017*(np.linspace(1800,2021,100)-1820)),
        '--',linewidth=3,color=myColor['tolVibrantOrange'])
ax.plot(data_Mad['year'],data_Mad['GDP_USA'],
                    '-',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='U.S. GDP per capita')
ax.minorticks_off()   
ax.set_yticks([2000,4000,8000,16000,32000,64000])

ax.legend(loc='upper left');

# %%
data_codes = ['USA','GBR','ITA','JPN','CHN','BRA','ETH']

data_GDP = dict()
for ind,c in enumerate(data_codes):
    ind_col = np.where(country_codes==c)
    data_GDP[c,'country_name'] = country_names[ind_col][0]
    col_GDP = data_Mad_GDP_pc[:,ind_col[0][0]]
    data_GDP[c,'year'] = data_Mad['year'][np.isnan(list(col_GDP))==False]
    data_GDP[c,'GDP'] = col_GDP[np.isnan(list(col_GDP))==False]

param = {'title': '',
         'xlim': [0,2021], 'ylim': [0,60000],
         'xlabel': '', 'ylabel': '2011 U.S. dollars',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': False, 'showNBERrecessions_y': [0,60000]}

fig,ax = myGenerateTSPlot(param)

for ind,c in enumerate(data_codes):
    ax.plot(data_GDP[c,'year'],data_GDP[c,'GDP'],
                        '-',linewidth=3,marker='',color=clist_1[ind],label=data_GDP[c,'country_name'] )
    
ax.legend(loc='upper left');

# %%
param = {'title': '',
         'xlim': [0,2021], 'ylim': [500,64000],
         'xlabel': '', 'ylabel': '2011 U.S. dollars',
         'ylogscale': True,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': False, 'showNBERrecessions_y': [0,60000]}

fig,ax = myGenerateTSPlot(param)

for ind,c in enumerate(data_codes):
    ax.plot(data_GDP[c,'year'],data_GDP[c,'GDP'],
                        '-',linewidth=3,marker='',color=clist_1[ind],label=data_GDP[c,'country_name'] )

ax.minorticks_off()   
ax.set_yticks([500,1000,2000,4000,8000,16000,32000,64000])
ax.legend(loc='upper left');

# %%
param = {'title': '',
         'xlim': [1800,2021], 'ylim': [500,64000],
         'xlabel': '', 'ylabel': '2011 U.S. dollars',
         'ylogscale': True,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': False, 'showNBERrecessions_y': [0,60000]}

fig,ax = myGenerateTSPlot(param)

for ind,c in enumerate(data_codes):
    ax.plot(data_GDP[c,'year'],data_GDP[c,'GDP'],
                        '-',linewidth=3,marker='',color=clist_1[ind],label=data_GDP[c,'country_name'] )

ax.minorticks_off()   
ax.set_yticks([500,1000,2000,4000,8000,16000,32000,64000])
ax.legend(loc='upper left');

# %% [markdown]
# ## Maddison project - regional data

# %%
# Maddison project data
data_Mad_reg_tab = pd.read_excel('https://www.rug.nl/ggdc/historicaldevelopment/maddison/data/mpd2020.xlsx',sheet_name="Regional data")
data_Mad_reg = data_Mad_reg_tab.to_numpy()

# %%
id_years = np.where(data_Mad_reg[:,0]*0 == 0,True,False)
region_codes = data_Mad_reg[0,1:9] # all regions
data_Mad_reg_GDP_pc = data_Mad_reg[id_years,1:9]
data_Mad_reg_year = data_Mad_reg[id_years,0]

region_names = region_codes        # selected regions
data_GDP = dict()
for ind,n in enumerate(region_names):
    ind_col = np.where(region_codes==n)
    data_GDP[n,'region_name'] = region_codes[ind_col][0]
    col_GDP = data_Mad_reg_GDP_pc[:,ind_col[0][0]]
    data_GDP[n,'year'] = data_Mad_reg_year[np.isnan(list(col_GDP))==False]
    data_GDP[n,'GDP'] = col_GDP[np.isnan(list(col_GDP))==False]

param = {'title': '',
         'xlim': [1820,2021], 'ylim': [500,60000],
         'xlabel': '', 'ylabel': '2011 U.S. dollars',
         'ylogscale': True,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': False, 'showNBERrecessions_y': [0,60000]}

fig,ax = myGenerateTSPlot(param)

for ind,n in enumerate(region_names):
    ax.plot(data_GDP[n,'year'],data_GDP[n,'GDP'],
                        '-',linewidth=3,marker='',color=clist_1[ind],label=data_GDP[n,'region_name'] )
    
ax.minorticks_off()   
ax.set_yticks([500,1000,2000,4000,8000,16000,32000,64000])
ax.legend(loc='upper left');
