# %% [markdown]
# # Topic 7: Inflation
#
# This lecture provides empirical evidence and theories of inflation.

# %%
# render graphs within notebook
# %matplotlib inline
# import relevant packages
import pandas as pd
import pandas_datareader as pdr
import numpy as np
import datetime

# load econutil package with some frequently used functions
import econutil as ec
# Out:
# Root package econutil imported.

# %% [markdown]
# # U.S. inflation
#
# U.S. inflation data from the <a href="https://fred.stlouisfed.org/">FRED database</a> at the Federal Reserve Bank of St. Louis.

# %%
# inflation data over a longer sample
data = ec.LoadDataFRED(series=['CPIAUCNS','CPILFESL'],transform='pct_change_year_ago')

param = {'title': '',
         'xlim': [1913,2026], 'ylim': [-20,25],
         'xlabel': 'year', 'ylabel': 'Percent Change from Year Ago',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-20,25]}

fig,ax = ec.GenerateTSPlot(param)

ax.plot(data['year'],data['CPIAUCNS'],
                    '-',linewidth=3,marker='',color=ec.tolColor['tolVibrantBlue'],label='Consumer Price Index: All Items')
#ax.plot(data['year'],data['CPILFESL'],
#                    linewidth=3,marker='',color=myColor['tolVibrantOrange'],label='Consumer Price Index: All Items Less Food and Energy')
x = ax.legend(loc='upper right')

# %%
# inflation data over a longer sample
data = ec.LoadDataFRED(series=['CPIAUCNS','CPILFESL'],transform='pct_change_year_ago')

param = {'title': '',
         'xlim': [1964,2026], 'ylim': [-2.5,15],
         'xlabel': 'year', 'ylabel': 'Percent Change from Year Ago',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-2.5,15]}

fig,ax = ec.GenerateTSPlot(param)

ax.plot(data['year'],data['CPIAUCNS'],
                    '--',linewidth=3,marker='',color=ec.tolColor['tolVibrantBlue'],label='Consumer Price Index: All Items')
ax.plot(data['year'],data['CPILFESL'],
                    linewidth=3,marker='',color=ec.tolColor['tolVibrantOrange'],label='Consumer Price Index: All Items Less Food and Energy')
x = ax.legend(loc='upper right')

# %% [markdown]
# ## Longer inflation time series, from MeasuringWorth.com
# http://www.measuringworth.com/datasets/uscpi/result.php

# %%
# load locally stored data
data_MW = pd.read_csv('data/USCPI_1774-2024.csv',skiprows=3)

param = {'figsize' : [15,9], 'fontsize': 16,
         'title': '',
         'xlim': [1774,2026], 'ylim': [-25,25],
         'xlabel': 'year', 'ylabel': 'inflation rate (%)',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-25,25]}

fig,ax = ec.GenerateTSPlot(param)

year = data_MW['Year'].to_numpy()
CPI = data_MW['U.S. Consumer Price Index *'].to_numpy()
inflation = (CPI[1:]-CPI[0:-1])/CPI[1:]*100

ax.plot(year[1:],inflation,'-',linewidth=3,marker='',color=ec.tolColor['tolVibrantBlue'],label='Consumer Price Index: All Items')

# %%
param = {'figsize' : [15,9], 'fontsize': 16,
         'title': '',
         'xlim': [1774,2026], 'ylim': [5,320],
         'xlabel': 'year', 'ylabel': 'consumer price index',
         'ylogscale': True,
         'showgrid': True, 'highlightzero': False,
         'showNBERrecessions': True, 'showNBERrecessions_y': [5,320]}

fig,ax = ec.GenerateTSPlot(param)

ax.plot(year,CPI,'-',linewidth=3,marker='',color=ec.tolColor['tolVibrantBlue'],label='Consumer Price Index: All Items')
ax.minorticks_off()   
ax.set_yticks([5,10,20,40,80,160,320]);

# %% [markdown]
# ## Gold prices

# %%
# price of gold - series discontinued
#data = myLoadDataFRED(series=['GOLDAMGBD228NLBM'],transform='none')

#param = {'title': '',
#         'xlim': [1968,2023], 'ylim': [32,2200],
#         'xlabel': 'year', 'ylabel': 'U.S. Dollars per Troy Ounce',
#         'ylogscale': True,
#         'showgrid': True, 'highlightzero': True,
#         'showNBERrecessions': True, 'showNBERrecessions_y': [30,2200]}

#fig,ax = myGenerateTSPlot(param)

#ax.plot(data['year'],data['GOLDAMGBD228NLBM'],
#                    '-',linewidth=3,marker='',color=myColor['tolVibrantBlue'],label='Gold Fixing Price in London Bullion Market, based on U.S. Dollars')
#x = ax.legend(loc='upper left')
#ax.minorticks_off()   
#ax.set_yticks([32,64,125,250,500,1000,2000]);

# %% [markdown]
# ## Real and nominal interest rates

# %%
# inflation data over a longer sample
data = ec.LoadDataFRED(series=['DGS5','DFII5','T5YIE'],transform='none')

param = {'title': '',
         'xlim': [2002,2026], 'ylim': [-2,6],
         'xlabel': 'year', 'ylabel': 'Percent',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-2,6]}

fig,ax = ec.GenerateTSPlot(param)

ax.plot(data['year'],data['DGS5'],
                    '-',linewidth=3,marker='',color=ec.tolColor['tolVibrantBlue'],label='5-Year Treasury Constant Maturity Rate')
ax.plot(data['year'],data['DFII5'],
                    '--',linewidth=3,marker='',color=ec.tolColor['tolVibrantOrange'],label='5-Year Treasury Inflation-Indexed Security, Constant Maturity')
x = ax.legend(loc='upper right')
ax.set_xticks([2002,2004,2006,2008,2010,2012,2014,2016,2018,2020,2022,2024,2026]);

param = {'title': '',
         'xlim': [2002,2026], 'ylim': [-3,4],
         'xlabel': 'year', 'ylabel': 'Percent',
         'ylogscale': False,
         'showgrid': True, 'highlightzero': True,
         'showNBERrecessions': True, 'showNBERrecessions_y': [-3,4]}

fig,ax = ec.GenerateTSPlot(param)

ax.plot(data['year'],data['T5YIE'],
                    '-',linewidth=3,marker='',color=ec.tolColor['tolVibrantBlue'],label='5-Year Breakeven Inflation Rate')
x = ax.legend(loc='upper right')
ax.set_xticks([2002,2004,2006,2008,2010,2012,2014,2016,2018,2020,2022,2024,2026]);
